# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
# %pip install netcdf2csv
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade pip
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Note: you may need to restart the kernel to use updated packages.

# %%
import xarray as xr
# %pip install netcdf4 h5netcdf
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Note: you may need to restart the kernel to use updated packages.

# %%
groundfrost = xr.open_dataset('groundfrost_hadukgrid_uk_25km_ann-30y_199101-202012.nc')
groundfrost.to_dataframe()
# Out:
#                                                                  groundfrost  \
# time       projection_y_coordinate projection_x_coordinate bnds
# 1991-07-01 -87500                  -187500                 0             NaN
#                                                            1             NaN
#                                    -162500                 0             NaN
#                                                            1             NaN
#                                    -137500                 0             NaN
# ...                                                                      ...
#             1187500                 712500                 1             NaN
#                                     737500                 0             NaN
#                                                            1             NaN
#                                     762500                 0             NaN
# ...

# %%
pv = xr.open_dataset('pv_hadukgrid_uk_25km_ann-30y_199101-202012.nc')
pv.to_dataframe().to_csv('pv.csv')

# %%
rainfall = xr.open_dataset('rainfall_hadukgrid_uk_25km_ann-30y_199101-202012.nc')
rainfall.to_dataframe().to_csv('rainfall.csv')

# %%
snowlying = xr.open_dataset('snowLying_hadukgrid_uk_25km_ann-30y_199101-202012.nc')
snowlying.to_dataframe().to_csv('snowlying.csv')

# %%
sun = xr.open_dataset('sun_hadukgrid_uk_25km_ann-30y_199101-202012.nc')
sun.to_dataframe().to_csv('sun.csv')

# %%
tasmax = xr.open_dataset('tasmax_hadukgrid_uk_25km_ann-30y_199101-202012.nc')
tasmax.to_dataframe().to_csv('tasmax.csv')

# %%
tasmin = xr.open_dataset('tasmin_hadukgrid_uk_25km_ann-30y_199101-202012.nc')
tasmin.to_dataframe().to_csv('tasmin.csv')

# %%
tasmin = pd.read_csv('tasmin.csv')
import matplotlib.pyplot as plt
import numpy as np

# %%
tasmin.head()
# Out:
#          time  projection_y_coordinate  projection_x_coordinate  bnds  tasmin  \
# 0  1991-07-01                   -87500                  -187500     0     NaN
# 1  1991-07-01                   -87500                  -187500     1     NaN
# 2  1991-07-01                   -87500                  -162500     0     NaN
# 3  1991-07-01                   -87500                  -162500     1     NaN
# 4  1991-07-01                   -87500                  -137500     0     NaN
#
#    transverse_mercator   time_bnds  projection_y_coordinate_bnds  \
# 0          -2147483647  1991-01-01                     -100000.0
# 1          -2147483647  2020-12-31                      -75000.0
# 2          -2147483647  1991-01-01                     -100000.0
# 3          -2147483647  2020-12-31                      -75000.0
# 4          -2147483647  1991-01-01                     -100000.0
#
#    projection_x_coordinate_bnds   latitude  longitude
# ...

# %%
tasmin['time']
# Out:
# 0       1991-07-01
# 1       1991-07-01
# 2       1991-07-01
# 3       1991-07-01
# 4       1991-07-01
#            ...
# 4051    1991-07-01
# 4052    1991-07-01
# 4053    1991-07-01
# 4054    1991-07-01
# 4055    1991-07-01
# Name: time, Length: 4056, dtype: object

# %%
tasmin['date_parsed'] = pd.to_datetime(tasmin['time_bnds'], format ="%Y/%m/%d")

# %%
tasmin.drop('time_bnds', axis=1)
tasmin.drop('time', axis=1)
# Out:
#       projection_y_coordinate  projection_x_coordinate  bnds  tasmin  \
# 0                      -87500                  -187500     0     NaN
# 1                      -87500                  -187500     1     NaN
# 2                      -87500                  -162500     0     NaN
# 3                      -87500                  -162500     1     NaN
# 4                      -87500                  -137500     0     NaN
# ...                       ...                      ...   ...     ...
# 4051                  1187500                   712500     1     NaN
# 4052                  1187500                   737500     0     NaN
# 4053                  1187500                   737500     1     NaN
# 4054                  1187500                   762500     0     NaN
# 4055                  1187500                   762500     1     NaN
#
#       transverse_mercator   time_bnds  projection_y_coordinate_bnds  \
# 0             -2147483647  1991-01-01                     -100000.0
# ...

# %%
tasmin.dropna(subset="tasmin")
# Out:
#             time  projection_y_coordinate  projection_x_coordinate  bnds  \
# 418   1991-07-01                    37500                   162500     0
# 419   1991-07-01                    37500                   162500     1
# 420   1991-07-01                    37500                   187500     0
# 421   1991-07-01                    37500                   187500     1
# 498   1991-07-01                    62500                   187500     0
# ...          ...                      ...                      ...   ...
# 3951  1991-07-01                  1162500                   437500     1
# 4028  1991-07-01                  1187500                   437500     0
# 4029  1991-07-01                  1187500                   437500     1
# 4030  1991-07-01                  1187500                   462500     0
# 4031  1991-07-01                  1187500                   462500     1
#
#         tasmin  transverse_mercator   time_bnds  projection_y_coordinate_bnds  \
# ...

# %% [markdown]
# I dont even know what this graph is plotting

# %%
plt.plot(tasmin['tasmin'])

# %%
mintemps = pd.read_csv('30yrmintemps.csv')

# %%
mintemps.head()
# Out:
#    year  jan  feb  mar  apr  may  jun   jul   aug  sep  oct  nov  dec    win  \
# 0  1884  2.7  1.4  1.8  2.2  5.0  7.9  10.3  10.5  9.0  4.9  1.8  0.9    ---
# 1  1885 -0.3  1.3 -0.1  2.5  3.5  7.8   9.5   8.1  6.8  3.1  2.3  0.3   0.61
# 2  1886 -1.5 -1.8 -0.1  2.2  4.7  7.5   9.8  10.0  8.1  6.9  3.0 -1.7  -0.96
# 3  1887 -0.7  0.2 -0.1  0.9  4.6  8.8  10.6   9.0  6.8  2.9  1.2 -0.7  -0.75
# 4  1888  0.2 -1.4 -0.9  1.7  4.6  7.3   8.7   8.8  7.0  3.8  4.2  1.6  -0.64
#
#     spr   sum   aut   ann
# 0  3.01  9.59  5.24  4.88
# 1  1.97  8.48  4.03  3.74
# 2  2.24  9.10  5.99  3.94
# 3  1.80  9.46  3.64  3.65
# 4  1.78  8.29  4.97  3.80

# %% [markdown]
# I decided to load in just recorded min temps for the uk from 1884 - 2020 and use that to visualise some min temps

# %%
plt.plot(mintemps['year'], mintemps['ann'])

# %%
tasmin.head()
# Out:
#          time  projection_y_coordinate  projection_x_coordinate  bnds  tasmin  \
# 0  1991-07-01                   -87500                  -187500     0     NaN
# 1  1991-07-01                   -87500                  -187500     1     NaN
# 2  1991-07-01                   -87500                  -162500     0     NaN
# 3  1991-07-01                   -87500                  -162500     1     NaN
# 4  1991-07-01                   -87500                  -137500     0     NaN
#
#    transverse_mercator   time_bnds  projection_y_coordinate_bnds  \
# 0          -2147483647  1991-01-01                     -100000.0
# 1          -2147483647  2020-12-31                      -75000.0
# 2          -2147483647  1991-01-01                     -100000.0
# 3          -2147483647  2020-12-31                      -75000.0
# 4          -2147483647  1991-01-01                     -100000.0
#
#    projection_x_coordinate_bnds   latitude  longitude date_parsed
# ...

# %%
# %pip install folium
import folium
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn
# %pip install pyimpute
# %pip install rasterio
# %pip install geopandas
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#   Using cached pyimpute-0.3.tar.gz (7.7 kB)
#   Preparing metadata (setup.py) ... done
# ...

# %%
import geopandas as gpd
import shutil
import glob
